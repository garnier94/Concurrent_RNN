# %%
import os
os.environ["OMP_NUM_THREADS"] = "20" 
os.environ["MKL_NUM_THREADS"] = "22"

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
import datetime as dt
import torch.nn.functional as F
from src import STD_DATA_DIR
from sklearn.preprocessing import MinMaxScaler
# Out:
# /home/CDBDX/remy.garnier/.virtualenvs/python_3.6_TS/lib/python3.6/site-packages/pandas/compat/__init__.py:85: UserWarning: Could not import the lzma module. Your installed Python is incomplete. Attempting to use lzma compression will result in a RuntimeError.
#   warnings.warn(msg)
# /home/CDBDX/remy.garnier/.virtualenvs/python_3.6_TS/lib/python3.6/site-packages/pandas/compat/__init__.py:85: UserWarning: Could not import the lzma module. Your installed Python is incomplete. Attempting to use lzma compression will result in a RuntimeError.
#   warnings.warn(msg)

# %% [markdown]
# # Prédiction des ventes par réseau de neurones récurrents
#
# Objectif :
# - Construire un réseau de neurones récurrents (LSTM) pour prédire les prochaines ventes sur quelques catégories
# - Comparer les approches avec & sans concurrence
# - Identifier les catégories pertinentes pour ce type d'approche
#
# ## I Données
# #### I.A Importation des données & premier traitements

# %%
data = pd.read_csv(STD_DATA_DIR /'dt_for_nn.csv', sep = ';')
data.set_index(['product','date'], inplace = True)
data = data[data.index.get_level_values(1) > '2017-01-01']

# %%
backfills_cols = ['prix_moy','prix_min_marche_moy','marge_srp','min_marche','min_mp','pump','marge_pump_avg']
for col in backfills_cols:
    data[col] = data[col].groupby(level = 0).fillna(method = 'bfill')
    data[col] = data[col].groupby(level = 0).fillna(method = 'ffill')

# %%
#del(data)
data = pd.read_csv(STD_DATA_DIR / 'filtered_dt_for_nn', sep = ';')
# Out:
# /home/CDBDX/remy.garnier/.virtualenvs/python_3.6_TS/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3049: DtypeWarning: Columns (1,8) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
#data.to_csv(STD_DATA_DIR / 'filtered_dt_for_nn', sep = ';')

# %%
set(data ['Niv. 3'])
# Out:
# {'SOIN DU SIÈGE',
#  'Chauffage et brumisateur ext',
#  'Accessoires electro',
#  'Divers Composants',
#  'Jeux de Bain - Hochets',
#  'Plant de légume',
#  'ACCESSOIRES ET DETERGENTS',
#  '***HS***Bougie Photophore',
#  'Ventilateurs/Refroidissement',
#  'Autre outil électroportatif',
#  'Interrupteur - prise - douille',
#  'Nourriture poisson',
#  'Talc',
#  'Classeur',
#  'Couchage chien',
#  "TV LED 4K de plus de 55''",
#  'Voitures Miniatures - CS',
#  'Peinture - Dessin - Coloriage',
#  'Biberons',
#  'Cages et accessoires rongeur',
#  'Courant Porteur - répéteurs',
#  'Ampoule fluorescente',
#  'Cave multi-température (P)',
#  'Accessoire de porte',
#  'Tournevis - Visseuse électric',
#  'Poeles wok sauteuse',
#  'Pot crayon-Sous main-Corbeille',
#  "TV LED FHD moins de 24''",
#  'Poussette multiple',
#  'CAble Jack',
#  'Rangement chambre Adulte',
#  'Robots radiocommandés',
#  'Matériel soudage',
#  'Accessoires disques durs',
#  'Fenêtre abattante',
#  'Thermomètre',
#  'Etabli - tréteau',
#  'Receveur douche',
#  'Phytosanitaire',
#  'Accessoire salle de bain',
#  'Mixeur -  Batteur',
#  'Billards',
#  'Broyeur',
#  'Accessoires beauté féminine',
#  "TV LED 4K entre 51 et 55''",
#  'Habitat cheval',
#  'Petit Rangement chambre',
#  'Cleaning',
#  'ETUIS ET HOUSSES',
#  'Autres radiocommandés',
#  'Parasol',
#  'Figurines à collectionner',
#  'Groupe 0+ / 1 - CS',
#  'Matériel basse - cour',
#  'CAble RCA',
#  'Linge de plage',
#  'Salon de jardin',
#  'Réservoir wc et cuvette',
#  'Seau et Serpillère',
#  'DIVERS ACCESSOIRES TABLETTES',
#  'Brumisateur - Rafraichisseur',
#  'Coffret outils à main',
#  'Sorbetières - Machines à glace',
#  'Ingredients DLC',
#  "TV LED 4K entre 33 et 41''",
#  'Couveuses',
#  'Griffoirs et arbres à chat',
#  'Modelage - Moulage',
#  'Decoration de Fête',
#  'Maquettes - modeles reduits',
#  'Stickers',
#  'Lit superposés\xa0 - Mezzanines',
#  'Sur-matelas',
#  'Boîtiers PC',
#  'Table de mixage analogique',
#  "TV LED FHD de plus de 55''",
#  'Tronçonneuse',
#  'Coffret repas',
#  'Accessoires',
#  'Casque et Micro',
#  'Correspondance',
#  'Lecteur MP3',
#  'Playmobil',
#  'Accessoire wc',
#  "Portable 11-12''",
#  'Tampon - Etiqueteuse',
#  'Jouets Educatifs - CS',
#  'Lave Linge (E)',
#  'Console',
#  'Planches de poussettes',
#  'Détection - mesure',
#  'Trotteur',
#  'Tapis comtemporain',
#  'Peintures - Couleurs',
#  'wc suspendu',
#  'Veilleuse',
#  'Décoration - Supports',
#  'Presse agrume - Centrifugeuse',
#  'Huile additif moteur - Danger',
#  'Perforateur- Burineur',
#  'Télécommande',
#  'Amplificateurs',
#  'Plinthe',
#  "Lits d'appoint",
#  'Ensemble memoire',
#  "Porte d'intérieur",
#  'Imprimante 3D',
#  'Guitares',
#  'Pompe de forage',
#  'CODODOS',
#  'Ventilateur mobile',
#  'Lave vaisselle (E)',
#  'Commodes - plan à langer',
#  'Accessoires beauté masculine',
#  'Rangement chambre Enfant',
#  'Hivernage des végétaux',
#  'Chauffage élec à inertie sèche',
#  'Batterie et percussions',
#  'Accessoires cuisson',
#  'Multimédia / Loisirs',
#  'Textiles cheval',
#  'Mémo-Loto-Domino-7 Famil-Magne',
#  'Table basse',
#  'Boîtiers externes',
#  'Gamelle et distributeur chien',
#  'Lego',
#  'Tondeuse autoportée',
#  'Pack électroportatif',
#  'Cuiseur à riz',
#  'Ballon eau chaude - chauffeau',
#  'iMac',
#  'Scie stationnaire',
#  'Console extensible',
#  'Emballage cadeau',
#  'Mijoteur - Wok',
#  "Gestion de l'énergie",
#  'Dinette - Cuisine - CS',
#  'Gazon  artificiel',
#  'Dressage chat',
#  'Chemise - Sous chemise',
#  'Fondue',
#  'Home Studio',
#  'Tapis Fantaisie',
#  'Matelas',
#  'Jeu scientifique - Expérience',
#  'Surligneur - Marqueur',
#  'Friteuse',
#  'Pinceaux et couteaux',
#  'Table à repasser',
#  'CALCULATRICE',
#  'Théière - chocolatière - bouil',
#  'Plant de fraisier',
#  'Porteurs - Trotteurs - CS',
#  'Soin du corps',
#  'Eclairage extérieur',
#  'Perceuse',
#  'Plante verte',
#  'Volet roulant',
#  'TAPIS VYNILE',
#  'Intercalaire-Pochette perforee',
#  'Agenda et calendrier',
#  "Récupérateur d'eau de pluie",
#  "Stations d'accueil",
#  'Cuisine complète',
#  'Piscine autostable tubulaire',
#  'Marchande - Tâche Ménagère',
#  'Accessoire mobilier jardin',
#  'Ensemble repas de jardin',
#  'Ensembles Home Cinema',
#  'Lits simples',
#  'Ponceuse',
#  'Compote - petit pot gouter',
#  'Mémoires RAM',
#  'Groupe 0+',
#  'Drap Housse',
#  'Plaid',
#  'Céréales',
#  'Nourriture oiseau',
#  'Tour de rangement',
#  'CLIC CLAC',
#  'Garages-Parkings-Circuits - CS',
#  'Aquariums',
#  'Lampe à poser',
#  "Desserte - Table d'appoint",
#  'Chancelière auto',
#  'Transmetteur - Amplificateur',
#  'Carrelage intérieur',
#  'Mobiles',
#  'Soins et hygiène cheval',
#  '***HS***Récepteur-Décodeur TNT',
#  'Tetines et sucettes',
#  'Tête de lit Adulte',
#  'Découpage - Collage',
#  'Jouets à tirer-Radiocommandés',
#  'Groupe 0+ - CS',
#  'Sommier tapissier',
#  'Perceuse à colonne',
#  'Ombrelles',
#  'Logiciels Pro',
#  'Matelas mousse',
#  "TV LED FHD entre 42 et 47''",
#  'Colles - Danger',
#  'Chauffage élec inertie fluide',
#  'Correcteur - Effaceur',
#  'Objet suspendu',
#  'Hotte',
#  'Cave à vin de service (E)',
#  'BANQUETTE CONVERTIBLE',
#  'Intra-auriculaires',
#  'Fauteuil Relaxation',
#  'Autre décoration murale',
#  'Parabole - Antenne RAteau',
#  'Coussins',
#  'Affiche poster',
#  'Outillage pneumatique',
#  'Beauté - Bijoux',
#  '27" et plus',
#  'Platines CD',
#  'PROTECTION LITERIE',
#  'Babyphone',
#  'Autres',
#  'Climatisation mobile',
#  "TV LED FHD entre 24 et 29''",
#  'Coffret et trousse de soin',
#  'Casseroles',
#  'Autres accessoires',
#  'Crédence et fond de hotte',
#  'Jeu apprentissage - Expérience',
#  'Barrière De Lit',
#  'Toners',
#  'Grill - Pierrade',
#  'Accessoires Repassage',
#  'Instruments de musique',
#  'Transport et accessoires chat',
#  'MINI PC',
#  'Sterilisateurs',
#  'Horloges',
#  'CAble optique',
#  'Motoculteur - motobineuse',
#  'Comme les Héros',
#  'Clés 128 Go ou plus',
#  'Défonceuse',
#  'Dictaphones',
#  'Anti-mousse',
#  'Autres mobiliers',
#  'Bougies Senteurs',
#  'Lutte fourmis - insectes',
#  'Lecteurs Blu-Ray',
#  'Crochet - access de suspension',
#  'Wifi / Bluetooth / Sans Fil',
#  'All in One',
#  'Lit parapluie couffin',
#  'Platines Vinyles',
#  'Loisir du chien',
#  'Micro ondes (E)',
#  'Accessoires Beauté Bien etre',
#  'Cave à vin vieillissement (P)',
#  'Ensemble claviers et souris',
#  'Lit parapluie combiné',
#  'Mosaïque',
#  'Portail coulissant',
#  'Décoration Chambre',
#  'Protection incendie',
#  'Papier peint',
#  'Access installation électrique',
#  'Alimentations',
#  'Gestion de la lumière',
#  'Sommier',
#  'Raccord - robinet - arrosoir',
#  "Jeux d'éveil",
#  'Lit parapluie simple',
#  'Construction plastique',
#  'Acces sol intérieur - colle',
#  'Micro ondes (P)',
#  'Terreau',
#  'Accessoires hygiène et soins',
#  'Refrigerateur (P)',
#  'Divers Réseau',
#  'Anneaux de dentition',
#  "TV LED FHD entre 30 et 32''",
#  'Manettes, Joysticks, Volants',
#  'Webcams, surveillance',
#  'Accessoire volet',
#  'Antenne Intérieure',
#  'Inférieur ou égal à 22"',
#  'Ecouteurs sports',
#  'Batteries',
#  'Body',
#  'Autres jeux de bar',
#  'Sieges de table',
#  'Tondeuse électrique',
#  'Film et tunnel de forçage',
#  'Jeu-construction-Habilete - CS',
#  'Isolation',
#  'Sous-couche - enduit - colle',
#  "Jeux d'Apprentissage",
#  'Cartes mères',
#  'Combustible',
#  'Décoration de noël',
#  'Pate à modeler - CS',
#  'Protege document-Couvre livre',
#  'Aspirateur à main',
#  'Protection des mains',
#  'Plante fleur - graminé - bulbe',
#  'Evier',
#  'Sécurité - Danger chien',
#  'Armoires Adulte',
#  'Papier dessin',
#  'Jus de fruits',
#  'Alimentation et évacuation eau',
#  'Cadre',
#  'Deshumificateur',
#  'Poubelle à pédale',
#  'Accessoires chaises hautes',
#  'Acces fenêtre et baie vitrée',
#  "TV LED 4K entre 48 et 50''",
#  'Photophore Bougeoir',
#  'Luminothérapie',
#  "TV LED FHD entre 48 et 50''",
#  'Mini four (P)',
#  'Carillon - sonnette',
#  'Scie à bûches',
#  'Loisir - Jouets rongeur',
#  'Lanterne',
#  'Vestiaire meubles à chaussures',
#  'Coupe bordures',
#  'Robinetterie lavabo',
#  'Sécurité - Danger chat',
#  'BALANCELLE',
#  'Marquise',
#  'Groupe 2 / 3 - CS',
#  'Enclos - Clapiers',
#  'Accessoires Froid',
#  'Meuleuse',
#  'Garages - Parkings - Circuits',
#  'Elagueuse',
#  'Abri en bois',
#  'Poire',
#  'Bases de fixation - CS',
#  'CAble Péritel',
#  'Boîte - coffre',
#  'Casque VR',
#  'Puzzles',
#  'Groupe électrogène',
#  "TV LED FHD entre 51 et 55''",
#  'Compresseur',
#  'Brosse - pinceau - rouleau',
#  '***HS***Accessoires de cuisine',
#  'Etagère murale',
#  'Ensemble relaxation',
#  'Nourriture Chien',
#  'Plante artificielle décorative',
#  'Trieur - Porte vues',
#  'Fille',
#  'Congelateur (P)',
#  'CRÈME DE SOIN',
#  'Chaine Hi-Fi',
#  'Graveurs DVD + Lecteur',
#  'Autres cAbles-connectique',
#  'Platines vinyle',
#  'Cheminée',
#  'CEINTURE DE GROSSESSE',
#  "Pompe d'arrosage",
#  'Accessoires de cuisines',
#  "Traitement de l'eau",
#  'Petit rangement salon séjour',
#  "Sport et jeux d'extérieur",
#  'Jouets Educatifs Et Musicaux',
#  'Accessoires literie',
#  'Barbecue',
#  'Tour de lit',
#  'Mémo-Loto-Domino',
#  'Cabine de douche',
#  'Accessoire cuisine',
#  'Cactée et plante grasse',
#  'Lampe torche - lampe frontale',
#  'wc à poser',
#  'Accessoires Petit Déjeuner',
#  'Chauffage élec à panneau rayon',
#  'Autre Plein Air',
#  'Antiparasitaires chien',
#  'Rangement Bureau Adulte',
#  'Nourriture Chats',
#  'DISQUE SSD',
#  'CAble HDMI - Splitter',
#  'Ardoise-Tapis magique-Tableau',
#  'Amplis et effet',
#  'Lits combinés',
#  'Basses & Guitares',
#  'Couteaux',
#  'Tapis classique',
#  'Robots mixeurs',
#  'Box domotique',
#  'Nurserie - Poussettes',
#  'Disques SSD externes',
#  'Transats et anneaux de bain',
#  'Chaussure - botte de sécurité',
#  '***HS***Star Wars',
#  'Chromebook',
#  'Accessoire pour semi',
#  'Accessoires de lit',
#  'Accessoire Sécurité Domestique',
#  'Bureau Enfant',
#  'Barre de son',
#  'Lampes LED',
#  'Chariot - diable',
#  'Fontaine intérieur Jardin zen',
#  'Chambre adulte',
#  "TV LED HD moins de 24''",
#  'Kit solaire -photovoltaïque',
#  'Pots et reducteurs',
#  'Rasage',
#  'Friandise et complément chat',
#  'Amplis & Effets',
#  'Matériel DJ',
#  'Coton',
#  'Miroir',
#  'Feutrecoloriage Crayoncouleur',
#  'Quincaillerie du meuble',
#  'Produits spéciaux',
#  'Cartes son',
#  'Mobilier enfant',
#  'Arbuste',
#  'Circuits électrique',
#  'Marchande - Tâche ménagère',
#  'Raccordement wc',
#  'Décapeur - décolleuse',
#  'Smart Box TV - Clé miracast',
#  'Switch/Hub USB/KVM',
#  'Serre tunnel et maraîchère',
#  'BOITE AUX LETTRES',
#  'Poubelle encastrable',
#  'Routeurs - modems',
#  'Lave Linge (P)',
#  'Logiciels',
#  'Parquet',
#  'Cartes à jouer - collectionner',
#  'Table de cuisson (E)',
#  'Instruments à cordes',
#  'Centrale vapeur',
#  'Tapis de souris Gaming',
#  'Coffre et armoire de rangement',
#  'CONSERVATION',
#  'Vitrine-Vaisselier-argentier',
#  'Composteur',
#  'Accessoires table à repasser',
#  'Divers Périphériques PC',
#  'Expresso',
#  'Purificateur-Lampe anti-insect',
#  'Huile de bain - shampoing',
#  'Lit enfant',
#  'Enceintes',
#  'Rangement bureau',
#  'Chaise Salle À Manger',
#  'Bibliothèque - étagère',
#  'Hochet',
#  'Linge de table',
#  'Lingettes',
#  'Soins et hygiène chien',
#  'Sommier lattes',
#  'Consoles-Tablettes éducatives',
#  'Maisons de Poupees - CS',
#  'Tableau électrique - composant',
#  'Clés 8 Go ou moins',
#  'Scarificateur',
#  'Motorisation portail',
#  'Housse de rangement',
#  'Soin et hygiène',
#  'Mixte',
#  'Cahier',
#  'Décodeurs TNT',
#  'Gamelle et distributeur chat',
#  'De 23" à 25"',
#  'Poupées mannequin',
#  'Support TV mural Fixe',
#  'Divers classement',
#  'Piscine acier',
#  'Epilation',
#  'Baby Foot',
#  'Plastification',
#  'Colle - Adhesif',
#  'Doudous',
#  'CAble coaxial',
#  'Observation, météo, cadre num',
#  'Ardoise et craie',
#  'Accessoires Lavage',
#  'Outil à main de jardin',
#  'Soins et hygiène reptile',
#  'Ensemble lit complet',
#  'TEST ADN',
#  'Tapis stylisés Orient',
#  'Tonnelle',
#  'Instruments à cordes (Quatuor)',
#  'Accessoires Cuisson GEM',
#  'Caméra IP',
#  'Purificateur',
#  'Tondeuse robot',
#  'Fouet à lait',
#  'Housse de couette',
#  'Autres instruments à cordes',
#  'Garçon',
#  'Robot patissier',
#  'Chauffage à bois',
#  'Tablettes sup à 10 pouces',
#  'Valet de chambre / portant',
#  'Accessibilité et sécurité SdB',
#  'Têtes à Coiffer',
#  'Ampli',
#  'Fer à repasser',
#  'Clés 16 Go',
#  'Coffre-fort - armoire à fusils',
#  'ONDULEURS ET PARAFOUDRES',
#  'Tapis de cuisine',
#  'ACCESSOIRES MATERNITÉ',
#  'Ensemble mousse',
#  'Poubelle de sdb',
#  'BZ',
#  'Enceintes - Haut-parleurs',
#  'Transats',
#  "Jeux d'Imitation",
#  'Armoires Enfant',
#  'Cafetière filtre',
#  'Machine à bière - tireuse',
#  'Véhicule à Thème',
#  'Appliques',
#  'Voitures radiocommandées',
#  'Jeux construction - Habileté',
#  '***HS***Meuble a chaussures',
#  'Groupe 2 / 3',
#  'Protection du corps',
#  'Nettoyeurs Vapeur',
#  'Garcon - CS',
#  'Bijoux et Perles',
#  'Accessoires biberon et sucette',
#  'Ferme - Nature',
#  'Support enceinte - barre son',
#  'Accessoires buanderie',
#  'Mediums, vernis et colles',
#  'Paroi de douche',
#  'Multicuiseur',
#  'Arbre',
#  'Jeux éducatifs électroniques',
#  'Construction magnétique',
#  'MOUCHE BÉBÉ MANUEL',
#  'CDR, DVDR, SAUVEGARDES',
#  'Poussette citadine',
#  'Claviers & Pianos',
#  'Poussette canne',
#  'Balai balayettes',
#  'Autocuiseurs',
#  'Traitement piscine - Danger',
#  'Aspirateur de chantier',
#  "Portables 13''",
#  'Linge de lit',
#  'Ventilateur',
#  'Balnéothérapie',
#  'Lecteur CD-MP3-Radio réveil',
#  'Rideaux et voilages',
#  'Aspirateur traineau',
#  'Lecteurs MP3 & MP4 (Vidéo)',
#  'Processeurs',
#  'Vêtement chien',
#  'Traitement - Entretien',
#  '***HS***Armoire-Dressing-Placa',
#  'Stérilisateur - Déshydrateur',
#  'Chassis et Chevalets',
#  'Sèche linge (P)',
#  'Paillassons',
#  'Mondes Imaginaires',
#  'Poterie-Plâtre-Pâte à sel',
#  'Autres textiles de chambre',
#  'Accessoire électroportatif',
#  'Table de jardin',
#  'Housses',
#  'Pulvérisateur et accessoire',
#  'Construction bois',
#  'Accessoires repassage couture',
#  'Accessoire mur intérieur',
#  'Cages et accessoires oiseau',
#  'Armoire et Dressing Adulte',
#  "Coussins d'allaitement",
#  'Autres câbles',
#  'Parcs',
#  'CHAUFFEUSES',
#  'Décoration-Accessoire poisson',
#  'Braséro',
#  'Niche',
#  'Machine à glaçons',
#  'Bavoirs et langes',
#  'Lecteur DVD portable',
#  'Tablettes 7 pouces ou moins',
#  'Couchage chat',
#  'Ordinateurs Educatifs',
#  'Insecticide',
#  'Spa',
#  'Meuble TV',
#  'Linge de décoration',
#  'Cheville - vis - clou - boulon',
#  'Buffet',
#  'CAble Satellite',
#  'Ensemble latex',
#  'Entretien de la piscine',
#  'Mini PC / Barebones',
#  'Jouets électroniques',
#  'Claviers et pianos',
#  'Controleurs numériques',
#  'Couvres lits et plaids',
#  'Radio Internet, K7, CD',
#  'Raccordement gaz',
#  "TV LED HD entre 30 et 32''",
#  'Purée de légume - plat préparé',
#  'Poussette 2 en 1',
#  'Poubelle automatique',
#  'Tapis enfant',
#  'LINGERIE HAUT',
#  'Scrapbooking',
#  'Vinyles',
#  'Eclairage chantier',
#  'Nettoyeur haute pression',
#  'Penderie souple',
#  'Casques TV - HiFi',
#  'Peluches',
#  'Housses - CS',
#  'Chambre enfant',
#  "Multifonction jet d'encre",
#  'Accessoire sol extérieur',
#  'Cuiseur vapeur',
#  'Cave à vin de service (P)',
#  'Sofas, fauteuils et poufs',
#  'Couverts',
#  'Pack Gamer',
#  'Peluches avec fonction',
#  'Coffrets cadeau',
#  'Habillages',
#  'Carré potager',
#  'Autres objets déco',
#  'Câbles Audio / Vidéo',
#  "Portables 15''",
#  'Jeux scientifiques',
#  'VÊTEMENT MATERNITÉ',
#  'Machine A Coudre',
#  'Meuble TV amplifié',
#  'Dinette - Cuisine',
#  'Robot nettoyeur',
#  'Piège',
#  'Autres accessoires TV-Antennes',
#  'Poupees mannequin - CS',
#  'Support vidéoprojecteur',
#  'Blender',
#  'Lampes enfants',
#  'Ensemble ressort',
#  'Vaisselle',
#  'Panoplies',
#  'Câbles USB',
#  'Piece detachee outils jardin',
#  'Jouets Educatifs',
#  'Découpage éléctrique',
#  'Fleur - Plante artificielle',
#  'Accessoires Instrument musique',
#  'Plan de travail',
#  'Jouet de bain',
#  "Imp. jet d'encre",
#  'Crayon-Porte mine-Taillecrayon',
#  "Pompe d'evacuation",
#  'Décorations de chambre',
#  'Canapé relaxation',
#  'Bahut - Buffet - Enfilade',
#  'Access Préparation Culinaire',
#  'Aspirateur souffleur',
#  'Câble - gaine',
#  'Haut-parleurs',
#  'Elément séparé SDB',
#  'Composition de plante',
#  'Verrerie Cache-pot Vide poche',
#  'Motorisation volet',
#  'Accessoire garage - rangement',
#  'Yaourtière - Fromagère',
#  'Balance de cuisine',
#  'TraÃ§age - Compas',
#  'Hamac de jardin',
#  'Outillage à main',
#  'Outil multifonctions',
#  'Matelas + sommier',
#  'Accessoires table',
#  'Crepière',
#  'Housse de protection',
#  'Soins et hygiène chat',
#  'Baignoire',
#  'Séjour Complet',
#  'Robinetterie de bain',
#  'Construction métal',
#  'Chevets - commodes Enfant',
#  'Cocotte',
#  'Piscines - Jeux de piscines',
#  '***HS***DISQUE DUR INTERNE',
#  'Chauffeuse',
#  'Radio réveil',
#  'Robot Cuiseur',
#  '***HS***Barbie',
#  'Hygiène',
#  'BERCEAUX',
#  'Chaises hautes',
#  "TV LED HD entre 24 et 29''",
#  'Access outillage stationnaire',
#  'Bâche',
#  'Piscine autostable',
#  'Protection de la tête',
#  "Portables 13'' tactiles",
#  "PRODUITS D'ENTRETIEN",
#  'Machine à pain, pâtes',
#  'Balancelles',
#  'Machine sous vide',
#  'Bureau Adulte',
#  'Ampoule halogène',
#  'Lasers - Lumières - Effets',
#  'Poupons et poupees - CS',
#  'Fiche bristol',
#  'Bonnet',
#  "Portables 17'' et sup",
#  'Grille Pain,Toasters',
#  'Desherbage',
#  'Spots',
#  "Vestiaire - meuble d'entrée",
#  'Lutte escargots - limaces',
#  'Article de déco et bouquet',
#  'Maisons de Poupées',
#  'Cuisinière (P)',
#  'Accessoires consommables',
#  'Mondes Imaginaires - CS',
#  '***HS***Imprimantes / Multifon',
#  'Pare soleil',
#  'Terrariums',
#  'Ampoule LED',
#  'Recepteurs Satellite',
#  'Vidéoprojecteurs',
#  'Fendeur',
#  'Groupe 0+ / 1 / 2 - CS',
#  'Multijeux',
#  'Abri résine et polycarbonate',
#  'Chaise Cuisine',
#  'Couture - Mercerie',
#  'Enrouleur-rallonge-multiprise',
#  'Humidificateur',
#  'NETTOYEUR SOL',
#  'Autres Petits rangement',
#  'Chauffe biberon',
#  'Barbecue charbon',
#  'Lit adulte',
#  'Soin dentaire',
#  'Tondeuse manuelle',
#  'Salle de bain complète',
#  'Déco - Accessoires reptiles',
#  'Lavante Séchante (P)',
#  'Vernis - lasure',
#  'Ecran de projection',
#  'Peluches avec fonction - CS',
#  'Poterie et platre',
#  'Pergola',
#  'Groupe 0 - nacelle',
#  'Enceintes Portables',
#  'Tricot - Crochet',
#  'Lutte rat - souris - taupe',
#  'Nourriture reptile',
#  'Piles',
#  'Antiparasitaires chat',
#  'Scie électrique',
#  'Lecteurs DVD - DivX',
#  'Sommier relaxation',
#  'Autres eveil',
#  'Friandise et complément cheval',
#  'Porte manteau - Patère',
#  'Filet - protection - paillage',
#  'Poussette canne - CS',
#  'Bout de canapé',
#  'Pèse bébé',
#  'Desserte',
#  'Claviers',
#  'Dalle et lame de terrasse',
#  'Accessoires VR',
#  'Accessoire chauffage',
#  'Batteries & percussions',
#  'Accessoires Cuisson PEM',
#  "TV LED FHD entre 33 et 41''",
#  'Petit rangement Cuisine',
#  'Débroussailleuse',
#  'Imp. Laser',
#  'Couette',
#  'Disques durs externes',
#  'Robinetterie de douche',
#  'Manutention levage',
#  'Brise soleil fenêtre et baie',
#  'Tapis de bain',
#  'Suspension plafonnier',
#  'Boite de classement-Archivage',
#  'Sécurité et Antivirus',
#  'Serrure - verrou - cadenas',
#  'Clés 32 Go',
#  'Enregistreur',
#  'Clés 64 Go',
#  'Autres Eléments séparés',
#  'FOURNITURES DE BUREAU',
#  'Accessoire portail',
#  'Support TV mural orientable',
#  'Caméra de surveillance',
#  'Unités centrales',
#  'Four (E)',
#  'Beauté-Mode-Perles-Bijoux',
#  'Tapis Eveil - Aire De Jeu - CS',
#  "Jeux d'eveil - CS",
#  'Bases de fixation',
#  'Broderie - Canevas',
#  "Portables < 11''",
#  'Pistolet-lance',
#  'Poussette 2 en 1 - CS',
#  'Cuisine - Parfum - Bougie',
#  'Lustre',
#  'Autre outil stationnaire',
#  'Consommables imprimante 3D',
#  'Canapé droit fixe',
#  'Rangement Bureau Enfant',
#  'Tablettes 8 pouces',
#  'Refrigerateur Americain (P)',
#  'Chauffage Mobile',
#  "Canapé d'angle fixe",
#  'Multifonction Laser',
#  'Tablettes 9 à 10 pouces',
#  'Gadgets - Objets insolites',
#  'Plaque de cuisson posable',
#  'Gazon',
#  'Electrostimulation',
#  'Micros',
#  '***HS***DISQUE SSD',
#  'Grillage',
#  'Chauffage eau chaude',
#  'Statuette Figurine Sculpture',
#  'Jeux de societe - CS',
#  'Kit de plantation',
#  'Engrais',
#  'Etagère - Plateau',
#  'Armoire - étagère',
#  'Lave vaisselle (P)',
#  '***HS***Claviers, souris, webc',
#  'Cartes graphiques',
#  'Poupons et poupées',
#  'Thermomètres',
#  'Biscuits bébé',
#  'Sac à langer',
#  'Maison toilette - Litière',
#  'Pots lumineux',
#  'Transport et accessoires chien',
#  'Sièges gamer',
#  'Petit déjeuner',
#  'Autre aménagement atelier',
#  'Tondeuses corps',
#  'Souris Gaming',
#  'Motorisation porte de garage',
#  'Canapé droit convertible',
#  'Alimentation basse - cour',
#  'ABAT-JOUR',
#  'Gros outillage de chantier',
#  'AUTRE DHP',
#  'Haie artificielle - brise vue',
#  'Etiquette - lien -  tuteur',
#  'LINGERIE BAS',
#  'Moule plat à four',
#  'DISQUES DURS INTERNES',
#  'Tuyau - enrouleur - accessoire',
#  'Macbook',
#  'Support TV Plafond',
#  'Couches',
#  '***HS***Rangement déco',
#  'Transats - CS',
#  'Accessoires santé connectée',
#  'Escabeau - échelle - échafauda',
#  'Groupe 1 / 2 / 3 - CS',
#  'Pompe - vide-cave - surpresseu',
#  'Tapis de souris',
#  'Dessin Et Graphisme',
#  'Barbecue gaz',
#  'Fontaine - bassin',
#  'Centre de repassage',
#  'Peluches-Poupées-Doudous',
#  'Garage et carport',
#  'Pyjama',
#  'Instruments à vent',
#  'Groupe 0 - nacelle - CS',
#  'Accessoires déguisement',
#  'Répulsif',
#  'Lampadaires',
#  'Poussette 3 en 1',
#  'Linge de bain',
#  'Accessoire porte de garage',
#  'Transat - bain de soleil',
#  'Crêpières gril',
#  'LAVE VITRE ELECTRIQUE',
#  'Convertibles',
#  'Buste - Mannequin',
#  'Boite aux lettres - accessoire',
#  'DOCKS ET SUPPORTS',
#  'MOUCHE BÉBÉ ÉLECTRIQUE',
#  'Coiffure',
#  'Autre produit gros oeuvre',
#  'Cale bébé et plan incliné',
#  'BANQUETTE FIXE ET MERIDIENNE',
#  'Chancelieres',
#  'Autre accessoire de peinture',
#  'Accessoires aspirateur',
#  'Autre linge de lit',
#  '***HS***Barbecue nomade',
#  'Souris',
#  'Balances',
#  'Chauffage élec convecteur',
#  'Cave multi-température (E)',
#  'Nourriture rongeur',
#  'Batteries, chargeurs, alimenta',
#  'Etau',
#  'Pyrogravure',
#  'Casques sans fils - Bluetooth',
#  'Lait bébé',
#  "Portables 14''",
#  'Accessoires repas',
#  'Accessoires de sdb',
#  'Cloture - grillage',
#  'Casques Réducteurs de bruit',
#  'Chauffage pétrole gaz',
#  'Jeux de société',
#  "Tapis D'Eveil Et Aires De Jeu",
#  'Lavabo - vasque - bidet',
#  'Chevaliers - Princesses',
#  'Beaute-Mode-Perles-Bijoux - CS',
#  'Sol vinyle',
#  'Traitement du bois',
#  'POULAILLER',
#  'Claviers Gaming',
#  'Tapis Shaggy mèches',
#  'Panier  / coffre',
#  'Matelas ressort',
#  'Textile jardinerie',
#  'Eclairage SDB',
#  'Sèche serviette',
#  'Disques durs réseau NAS',
#  'Climatisation',
#  'Bricolage - Outils',
#  'Alarme et détection',
#  'Lait - Liniment',
#  "Voile d'ombrage",
#  'Peinture extérieure',
#  'Ciment - chaux - mortier',
#  'Robot multifonctions',
#  'Accessoires allaitement',
#  'Poussette 3 roues - CS',
#  'Fax et Télécopieurs, autres',
#  'Voitures Miniatures',
#  'Baignoires et supports',
#  'Coton Tige',
#  'Tablette Graphique',
#  'Raclette',
#  'Plante fleurie',
#  'Machine à soda',
#  'Reliage - Destruction',
#  'SOIN VISAGE BÉBÉ',
#  'Petite domotique',
#  'Table à langer',
#  'Contenant - pot - cache pot',
#  'Véhicules et trottinettes',
#  'Chevets - commodes Adulte',
#  'Gaufrier - Croque Monsieur',
#  'Peinture - aérosol - Danger',
#  'Jeux de plage',
#  'Séchoirs',
#  'Colle et adhésif',
#  'Transport cheval',
#  'Poussette 3 roues',
#  'Hélicoptères-Avions RC',
#  'Papier photo',
#  'Tableaux',
#  'Papier standard',
#  'Barrière De Sécurité',
#  'Papier-peint',
#  'Soins et hygiène basse - cour',
#  'Robots',
#  'Stylo-FeutreEcriture-Cartouche',
#  'Acquisition vidéo',
#  'Fauteuil Classique',
#  'Circuits',
#  'Note repositionnable - Post it',
#  'Rehausseurs',
#  'Escalier',
#  'Tables à manger',
#  'Assiettes',
#  'Peinture intérieure',
#  'Pompe',
#  'Livre scolaire - Dictionnaire',
#  'Santé connectée',
#  'Chauffage mobile',
#  '***HS***Pouf chauffeuse banc',
#  'Concentrés',
#  'Taille-haies',
#  'Tabouret',
#  'Laisserie chien',
#  ...}

# %%
data = pd.read_csv(STD_DATA_DIR / 'filtered_dt_for_nn', sep = ';')
data.set_index(['product','date'], inplace = True)
# Out:
# /home/CDBDX/remy.garnier/.virtualenvs/python_3.6_TS/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3049: DtypeWarning: Columns (1,8) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %% [markdown]
# ### I.B Filtrage des données

# %%
index ='Vente lisse' #index usuel utilisé pour le filtrage

def filter_by_level(data,fam, niv='Niv. 3'):
    return data[data[niv] == fam]

def add_sum(data, fam, niv= 'Niv. 3'):
    df = filter_by_level(data, fam, niv)
    sum_df = df.groupby(level = 1)[index].sum()
    return df.join(sum_df, rsuffix ='_somme')

def extract_data(data, fam, niv= 'Niv. 3'):
    df = add_sum(data, fam, niv)
    df['part_de_marché']  = df[index]/df[index+'_somme']
    return df

fam = 'Aspirateur souffleur'
level = 'Niv. 3'
df = add_sum(data, fam, niv=level)

# %%
#Scaling
cols_to_scale =['prix_moy','prix_min_marche_moy','marge_srp', 'pump']
scaler = MinMaxScaler(feature_range=(0,10))
df[cols_to_scale] = scaler.fit_transform(df[cols_to_scale])

# %%
del(data)

# %% [markdown]
# ### I.C Adaptation des données à Pytorch

# %%
# filtre produit:
nb_ventes_mini = 100 #Nombre minimal de ventes                                                        
len_min =  10 # Nombre de semaines minimales de ventes

# %%
def gener_torch_dataset(data,split_date, col_drop =['Unnamed: 0','Vente lisse','min_marche', 'Vente réelle','Niv. 1','Niv. 2','Niv. 3'], horizon = 3 ):
    target =100*(data[index]/data[index+'_somme']).shift(horizon).iloc[horizon:]
    y_train = torch.tensor(target[target.index < split_date].values, dtype = torch.float32)
    y_test = torch.tensor(target.values, dtype = torch.float32)
    
    
    X = data[horizon:]
    #X['truth'] = 100 * data[index]/data[index+'_somme']
    X.drop(columns = col_drop, inplace= True)
    X['pdM'] = 100 * data[index]/data[index+'_somme']
    
    n_item = X.shape[1]
    X_train =  torch.tensor(X[X.index < split_date].values, dtype= torch.float32).reshape(-1,1,n_item)
    X_test = torch.tensor(X.values, dtype= torch.float32).reshape(-1,1,n_item)
    return X_train, y_train, X_test,y_test, torch.tensor(X['pdM'], dtype = torch.float32)

# %%
train_list = []
test_list = []
keeped_products = []
date_train = '2019-01-01'
products = set(df.index.get_level_values(0))
for prod in products:
    vt_prod = df.loc[prod].fillna(0)
    if sum(vt_prod[index]) > nb_ventes_mini:
        min_date = min(vt_prod[vt_prod[index] > 0].index)
        max_date = min(date_train, max(vt_prod[vt_prod[index] > 0].index))
        
        min_date = dt.datetime.strptime(min_date, '%Y-%m-%d')
        max_date = dt.datetime.strptime(max_date, '%Y-%m-%d')
        
        if (max_date - min_date).days // 7 > len_min:
            keeped_products.append(prod)
            X_train, y_train, X_test,y_test,ref = gener_torch_dataset(vt_prod[vt_prod.index > dt.datetime.strftime(min_date,'%Y-%m-%d' )], date_train)
            train_list.append((X_train,y_train))
            test_list.append((X_test,y_test,ref))
            
print('Nb de produits initial  %s ' % len(products))
print('Nb de ventes initiales %s ' % sum(df[index]))
print('Nb de produits conservés %s' %len(keeped_products))        
print('Nb de ventes conservées %s' % sum(df[index].loc[keeped_products]))

# %%
X_train.shape

# %% [markdown]
# ## II Modèle sans concurrence
# #### II.A Réseau de neurones

# %%
class LSTM_nn(nn.Module):
    def __init__(self, n_param,n_hidden, n_layer):
        super().__init__()
        self.rnn = nn.LSTM(n_param,n_hidden,n_layer)
        self.hidden_layer = (torch.zeros(n_layer, 1,n_hidden),
                            torch.zeros(n_layer, 1 ,n_hidden))
        self.linear = nn.Linear(n_hidden,1)
        self.n_hidden = n_hidden
        
    def forward(self,x):
        output, self.hidden_layer = self.rnn(x, self.hidden_layer)
        return F.softplus(self.linear(output))
    
    def reinitialize(self):
        self.hidden_layer = (torch.normal(0,1,size=(n_layer, 1,self.n_hidden)),
                            torch.normal(0,1,size=(n_layer, 1,self.n_hidden)))

# %%
#Constantes 

epochs =1000
learning_rate =  1e-3
n_hidden = 5
n_param = X_train.shape[2]
n_layer =2

model = LSTM_nn(n_param,n_hidden,n_layer)
loss_function = nn.L1Loss(reduction ='sum')
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)

# %% [markdown]
# #### II.B Entrainement

# %%
from random import shuffle

err_train  = []
err_test =  []

for i in range(epochs):
    l=0
    s=0
    copy_train_list = train_list.copy()
    shuffle(copy_train_list)
    for X_train,y_train in copy_train_list:
        optimizer.zero_grad()
        model.reinitialize()
        y_pred = model(X_train)
        single_loss = loss_function(y_pred[-30:,0],y_train[-30:] )
        single_loss.backward()
        optimizer.step()
        l += single_loss.item()
        s += sum(y_train[-30:])
        
    l_test = 0
    s_t = 0
    l_ref = 0
    for X_test, y_test,ref  in test_list:
        model.reinitialize()
        y_pred = model(X_test)[-50:,0]
        single_loss = loss_function(y_pred,y_test[-50:] )
        l_test += single_loss.item()
        s_t+= sum(y_test[-50:])
        
        l_ref += loss_function(ref[-50:],y_test[-50:]).item()
    print('Training MAPE: %.4f  Testing MAPE: %.4f Ref : %.4F' %(l/s  , l_test/s_t,l_ref/s_t ))
    err_train.append(l)
    err_test.append(l_test)

# %%
X_train,y_train = train_list[5]
model.reinitialize()
model(X_train)[:,0,0]

# %%
X_train[:,0,:]

# %%
len(copy_train_list)

# %%
plt.figure(figsize=(12,7))
#plt.plot(lt_test_ref,'--', label =  'Test Error Reference', color = 'red')
#plt.plot(lt_train_ref,'--', label =  'Train Error Reference', color = 'blue')
plt.plot(err_test, label =  'Test Error Reference', color =  'red')
plt.plot(err_train, label =  'Train Error Reference', color =  'blue')
plt.legend()
plt.xlabel("Epoch")
#plt.yscale('log')
plt.show()

# %%
X_test,y_test,_ = test_list[3]

# %%
model.reinitialize()
y_pred = model(X_test)[-35:,0]
y_pred

# %%
sum(torch.abs(y_test[-35:] - y_pred[-35,:]))/sum(y_test[-35:])

# %%
sum(y_test[-35:])

# %%
loss_function(y_test[-35:],y_pred[-35,:]).item()

# %%
y_test

# %% [markdown]
# ## III A taille d'historique fixée
# #### III.A Construction des données

# %%
def gener_lagged_dataset(serie_prod, period, horizon, min_cons=10):
    N = len(serie_prod)
    l = []
    for i in range(N-period-horizon+1):
        X = torch.tensor(serie_prod.drop(columns = 'pdM').iloc[i:i+period, :].values, dtype = torch.float32).reshape(period,1,-1) 
        y = torch.tensor(serie_prod['pdM'].iloc[i+horizon:i+horizon+period], dtype = torch.float32).reshape(period,1,-1)
        if sum(y) >=min_cons:
            l.append([X,y])
    return l

def gener_dat(data, index, col_drop =['Unnamed: 0','Vente lisse','min_marche', 'Vente réelle','Niv. 1','Niv. 2','Niv. 3'], horizon=6):
    X = data.copy()
    X.drop(columns = col_drop, inplace= True)
    X['pdM'] = 100 * (data[index]/data[index+'_somme'])
    X['pdM_shift'] = X['pdM'].shift(horizon)
    return X.iloc[horizon:]

# %%
#paramètres 
len_min = 25
window =20
horizon = 4
date_train = '2019-01-01'
nb_ventes_mini = 100
n_calc = 10

# %%
l_train = []
l_valid =[]
keeped_products =[]

products = set(df.index.get_level_values(0))
for prod in products:
    vt_prod = df.loc[prod].fillna(0)
    if sum(vt_prod[index]) > nb_ventes_mini:
        min_date = min(vt_prod[vt_prod[index] > 0].index)
        max_date = min(date_train, max(vt_prod[vt_prod[index] > 0].index))
        
        min_date = dt.datetime.strptime(min_date, '%Y-%m-%d')
        max_date = dt.datetime.strptime(max_date, '%Y-%m-%d')

        if (max_date - min_date).days // 7 > len_min:
            keeped_products.append(prod)
            l_train += gener_lagged_dataset(gener_dat(vt_prod[vt_prod.index < dt.datetime.strftime(max_date,'%Y-%m-%d' )], index, horizon=horizon),window,horizon)
            l_valid += gener_lagged_dataset(gener_dat(vt_prod[vt_prod.index > (dt.datetime.strftime(max_date - dt.timedelta(days = 7*horizon),'%Y-%m-%d' ) )], index,horizon=horizon),window,horizon)
            
print('Nb de produits initial  %s ' % len(products))
print('Nb de ventes initiales %s ' % sum(df[index]))
print('Nb de produits conservés %s' %len(keeped_products))        
print('Nb de ventes conservées %s' % sum(df[index].loc[keeped_products]))
# Out:
# Nb de produits initial  104
# Nb de ventes initiales 21892.603540221062
# Nb de produits conservés 32
# Nb de ventes conservées 17383.077999857356

# %%
#Constantes

epochs =200
learning_rate =  5e-3
n_hidden = 20
n_param = l_train[0][0].shape[2]
n_layer =1

model = LSTM_nn(n_param,n_hidden,n_layer)
loss_function = nn.L1Loss(reduction ='sum')
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)

# %%
from random import shuffle


err_train  = []
err_test =  []

for i in range(epochs):
    l=0
    s=0
    copy_train_list = l_train.copy()
    shuffle(copy_train_list)
    
    optimizer.zero_grad()
    
    loss = 0
    for X_train,y_train in copy_train_list:
        model.reinitialize()
        y_pred = model(X_train)
        single_loss = loss_function(y_pred[-n_calc:,0],y_train[-n_calc:,0] )
        
        loss +=single_loss
        l += single_loss.item()
        s += sum(y_train[-n_calc:,0])
    loss.backward()
    optimizer.step()
        
    l_test = 0
    s_t = 0
    l_ref = 0
    for X_test, y_test  in l_valid:
        model.reinitialize()
        y_pred = model(X_test)
        single_loss = loss_function(y_pred[-n_calc:,0],y_test[-n_calc:,0] )
        l_test += single_loss.item()
        s_t+= sum(y_test[-n_calc:,0])
    if i % 5 ==0:
        print('Training MAPE: %.4f  Testing MAPE: %.4f' %(100 * l/s  , 100 * l_test/s_t))
    err_train.append(l)
    err_test.append(l_test)

# %%
plt.figure(figsize=(12,7))
#plt.plot(lt_test_ref,'--', label =  'Test Error Reference', color = 'red')
#plt.plot(lt_train_ref,'--', label =  'Train Error Reference', color = 'blue')
plt.plot(list(map(lambda x: 100 * x/float(s_t), err_test)), label =  'Test Error Reference', color =  'red')
plt.plot(list(map(lambda x: 100 * x/float(s), err_train)), label =  'Train Error Reference', color =  'blue')
plt.legend()
plt.xlabel("Epoch")
plt.ylabel('MAPE')
#plt.yscale('log')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-05c23f2e5244> in <module>
#       2 #plt.plot(lt_test_ref,'--', label =  'Test Error Reference', color = 'red')
#       3 #plt.plot(lt_train_ref,'--', label =  'Train Error Reference', color = 'blue')
# ----> 4 plt.plot(list(map(lambda x: 100 * x/float(s_t), err_test)), label =  'Test Error Reference', color =  'red')
#       5 plt.plot(list(map(lambda x: 100 * x/float(s), err_train)), label =  'Train Error Reference', color =  'blue')
#       6 plt.legend()
#
# NameError: name 'err_test' is not defined

# %% [markdown]
# ### La Même, avec competition

# %%
# filtre produit:
nb_ventes_mini = 0 #Nombre minimal de ventes                                                        
len_min =  0 # Nombre de semaines minimales de ventes

# %%
def gener_lagged_dataset_mat(serie_prod, period, horizon,matrix, index, min_cons=0):
    N = len(serie_prod)
    for i in range(N-period-horizon+1):
        X = torch.tensor(serie_prod.iloc[i:i+period, :].values, dtype = torch.float32).reshape(period,1,-1) 
        y = torch.tensor(serie_prod['pdM'].iloc[i+horizon:i+horizon+period], dtype = torch.float32).reshape(period,1,-1)
        if sum(y) >=min_cons:
            matrix[index+i].append([X,y])

def gener_dat(data, index, col_drop =['Unnamed: 0','Vente lisse','min_marche', 'Vente réelle','Niv. 1','Niv. 2','Niv. 3'], horizon=6):
    X = data.copy()
    X.drop(columns = col_drop, inplace= True)
    X['pdM'] = 100 * (data['Vente lisse']/data['Vente lisse'+'_somme'])
    X['pdM_shift'] = X['pdM'].shift(horizon)
    return X.iloc[horizon:]

# %%
date_start = dt.datetime.strptime( min(df.index.get_level_values(1)), '%Y-%m-%d')
date_end_training = dt.datetime.strptime(date_train, '%Y-%m-%d')
nb_weeks = (date_end_training - date_start).days //7

# %%
mat_train = [[] for i in range(nb_weeks)]
mat_test = [[] for i in range(54 + horizon)]

l_train = []
l_valid =[]
keeped_products =[]

products = set(df.index.get_level_values(0))
for prod in products:
    vt_prod = df.loc[prod].fillna(0)
    if sum(vt_prod[index]) > nb_ventes_mini:
        min_date = min(vt_prod[vt_prod[index] > 0].index)
        max_date = min(date_train, max(vt_prod[vt_prod[index] > 0].index))
    
        min_date = dt.datetime.strptime(min_date, '%Y-%m-%d')
        max_date = dt.datetime.strptime(max_date, '%Y-%m-%d')
        index_start = (min_date-date_start).days//7
        
        if (max_date - min_date).days // 7 > len_min:
            keeped_products.append(prod)
            red_prod = vt_prod[vt_prod.index <= dt.datetime.strftime(max_date,'%Y-%m-%d' )]
            red_prod = red_prod[red_prod.index >= dt.datetime.strftime(min_date,'%Y-%m-%d' )]
            
            valid_red_prod = vt_prod[vt_prod.index > (dt.datetime.strftime(date_end_training - dt.timedelta(days = 7*horizon),'%Y-%m-%d' ) )]

            gener_lagged_dataset_mat(gener_dat(red_prod, index, horizon=horizon),window,horizon, mat_train,index_start)
            gener_lagged_dataset_mat(gener_dat(valid_red_prod, index, horizon=horizon),window,horizon, mat_test,0)            
print('Nb de produits initial  %s ' % len(products))
print('Nb de ventes initiales %s ' % sum(df[index]))
print('Nb de produits conservés %s' %len(keeped_products))        
print('Nb de ventes conservées %s' % sum(df[index].loc[keeped_products]))
# Out:
# Nb de produits initial  104
# Nb de ventes initiales 21892.603540221062
# Nb de produits conservés 83
# Nb de ventes conservées 21005.874692294365

# %%
#Constantes

epochs =2000
learning_rate =  5e-3
n_hidden = 20
n_param = 10
n_layer =1

model = LSTM_nn(n_param,n_hidden,n_layer)
loss_function = nn.L1Loss(reduction ='sum')
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)

# %%
from random import shuffle


err_train_2  = []
err_test_2 =  []

for i in range(epochs):
    l=0
    s=0
    copy_train_list = mat_train.copy()
    shuffle(copy_train_list)
    
    optimizer.zero_grad()
    loss = 0
    for mat_step in copy_train_list:
        if len(mat_step) !=0:
            
            partial_sum= torch.tensor(mat_step[0][1])
            for i in range(1,len(mat_step)):
                partial_sum += mat_step[i][1]
        
            
            model.reinitialize()
            cp_mat_step = mat_step.copy()
            sum_prediction = torch.ones(partial_sum.shape)
            for X_train,_ in cp_mat_step:
                model.reinitialize()
                sum_prediction += model(X_train)

            shuffle(cp_mat_step)
            for (X_train,y_train) in cp_mat_step:
                model.reinitialize()
                y_pred = partial_sum * model(X_train)/sum_prediction
                single_loss = loss_function(y_pred[-n_calc:,0],y_train[-n_calc:,0] )
                loss += single_loss
                l += single_loss.item()
                s += sum(y_train[-n_calc:,0])
    loss.backward()
    optimizer.step()
            
    
    l_test = 0
    s_test = 0 
    for mat_step in mat_test: 
        if len(mat_step) !=0:
            partial_sum= torch.tensor(mat_step[0][1])
            for i in range(1,len(mat_step)):
                partial_sum += mat_step[i][1]
            optimizer.zero_grad()
            model.reinitialize()
            cp_mat_step = mat_step.copy()

            sum_prediction = torch.zeros(y_train.shape)
            for X_test,_ in cp_mat_step:
                model.reinitialize()
                sum_prediction += model(X_test)

            for (X_train,y_train) in cp_mat_step:
                model.reinitialize()
                y_pred = partial_sum * model(X_train)/sum_prediction
                single_loss = loss_function(y_pred[-n_calc:,0],y_train[-n_calc:,0] )
                l_test += single_loss.item()
                s_test += sum(y_train[-n_calc:,0])
    
    print('Training MAPE: %.4f Testing MAPE: %.4f' %(100 * l/s , 100 * l_test/s_test))
    err_train_2.append(l)
    err_test_2.append(l_test)
# Out:
# /home/CDBDX/remy.garnier/.virtualenvs/python_3.6_TS/lib/python3.6/site-packages/ipykernel_launcher.py:18: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
# /home/CDBDX/remy.garnier/.virtualenvs/python_3.6_TS/lib/python3.6/site-packages/ipykernel_launcher.py:46: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
# Training MAPE: 85.4388 Testing MAPE: 115.2496
# Training MAPE: 85.1531 Testing MAPE: 114.9988
# Training MAPE: 85.0788 Testing MAPE: 115.4934
# Training MAPE: 84.5405 Testing MAPE: 115.2309
# Training MAPE: 84.9282 Testing MAPE: 115.2025
# Training MAPE: 84.4866 Testing MAPE: 114.7804
# Training MAPE: 84.2930 Testing MAPE: 115.1383
# Training MAPE: 84.5122 Testing MAPE: 114.8590
# Training MAPE: 84.2360 Testing MAPE: 114.3299
# Training MAPE: 83.9423 Testing MAPE: 114.5561
# Training MAPE: 84.2792 Testing MAPE: 114.5532
# Training MAPE: 83.7342 Testing MAPE: 114.3624
# Training MAPE: 83.6859 Testing MAPE: 114.2583
# Training MAPE: 83.5847 Testing MAPE: 113.8489
# Training MAPE: 83.6070 Testing MAPE: 114.4449
# Training MAPE: 83.2321 Testing MAPE: 114.0974
# Training MAPE: 83.0975 Testing MAPE: 113.5963
# Training MAPE: 82.8151 Testing MAPE: 113.3061
# Training MAPE: 82.4069 Testing MAPE: 113.1362
# Training MAPE: 82.5682 Testing MAPE: 112.8396
# Training MAPE: 82.3789 Testing MAPE: 112.4771
# Training MAPE: 82.0738 Testing MAPE: 112.2274
# Training MAPE: 81.7713 Testing MAPE: 112.0701
# Training MAPE: 81.5600 Testing MAPE: 111.8205
# Training MAPE: 81.5372 Testing MAPE: 111.5317
# Training MAPE: 81.3209 Testing MAPE: 111.4629
# Training MAPE: 81.0264 Testing MAPE: 111.1324
# Training MAPE: 80.7878 Testing MAPE: 110.9769
# Training MAPE: 80.4310 Testing MAPE: 111.1115
# Training MAPE: 80.3701 Testing MAPE: 111.1192
# Training MAPE: 79.9618 Testing MAPE: 110.7856
# Training MAPE: 79.4473 Testing MAPE: 110.4785
# Training MAPE: 79.2195 Testing MAPE: 110.8227
# Training MAPE: 78.3794 Testing MAPE: 110.0484
# Training MAPE: 78.0289 Testing MAPE: 109.1644
# Training MAPE: 77.1153 Testing MAPE: 107.6550
# Training MAPE: 76.4872 Testing MAPE: 106.9666
# Training MAPE: 76.6447 Testing MAPE: 106.9857
# Training MAPE: 76.3143 Testing MAPE: 105.9870
# Training MAPE: 75.6790 Testing MAPE: 106.2031
# Training MAPE: 75.3392 Testing MAPE: 106.5829
# Training MAPE: 74.9291 Testing MAPE: 106.2975
# Training MAPE: 74.6029 Testing MAPE: 106.1348
# Training MAPE: 74.1916 Testing MAPE: 105.3262
# Training MAPE: 73.5377 Testing MAPE: 105.4160
# Training MAPE: 72.8418 Testing MAPE: 104.4133
# Training MAPE: 72.2323 Testing MAPE: 103.5914
# Training MAPE: 72.1324 Testing MAPE: 103.2479
# Training MAPE: 71.5417 Testing MAPE: 102.9089
# Training MAPE: 71.1517 Testing MAPE: 102.0886
# Training MAPE: 70.7052 Testing MAPE: 100.8545
# Training MAPE: 70.1096 Testing MAPE: 99.7335
# Training MAPE: 69.5111 Testing MAPE: 100.0698
# Training MAPE: 68.9602 Testing MAPE: 99.9572
# Training MAPE: 68.7027 Testing MAPE: 99.4305
# Training MAPE: 68.4537 Testing MAPE: 98.0033
# Training MAPE: 67.9639 Testing MAPE: 97.0002
# Training MAPE: 67.1104 Testing MAPE: 95.3185
# Training MAPE: 66.5307 Testing MAPE: 94.4548
# Training MAPE: 66.1115 Testing MAPE: 93.7051
# Training MAPE: 65.9444 Testing MAPE: 92.3176
# Training MAPE: 65.3373 Testing MAPE: 92.5647
# Training MAPE: 65.0239 Testing MAPE: 91.8039
# Training MAPE: 64.4548 Testing MAPE: 91.1594
# Training MAPE: 64.0110 Testing MAPE: 91.0242
# Training MAPE: 63.3169 Testing MAPE: 90.8322
# Training MAPE: 63.2600 Testing MAPE: 90.5376
# Training MAPE: 62.6845 Testing MAPE: 90.0358
# Training MAPE: 62.8092 Testing MAPE: 89.4407
# Training MAPE: 62.2294 Testing MAPE: 90.2451
# Training MAPE: 62.0152 Testing MAPE: 89.0508
# Training MAPE: 61.5492 Testing MAPE: 89.2795
# Training MAPE: 61.5111 Testing MAPE: 88.9822
# Training MAPE: 61.3598 Testing MAPE: 89.1814
# Training MAPE: 61.1307 Testing MAPE: 87.9437
# Training MAPE: 60.9155 Testing MAPE: 87.7664
# Training MAPE: 60.6231 Testing MAPE: 87.1238
# Training MAPE: 60.4217 Testing MAPE: 86.5117
# Training MAPE: 60.2047 Testing MAPE: 86.6859
# Training MAPE: 60.0178 Testing MAPE: 85.4865
# Training MAPE: 59.6978 Testing MAPE: 86.1012
# Training MAPE: 59.7533 Testing MAPE: 86.0091
# Training MAPE: 59.5287 Testing MAPE: 86.3666
# Training MAPE: 59.2026 Testing MAPE: 85.5105
# Training MAPE: 59.2236 Testing MAPE: 84.8174
# Training MAPE: 58.6802 Testing MAPE: 84.1109
# Training MAPE: 58.4998 Testing MAPE: 84.2977
# Training MAPE: 58.7603 Testing MAPE: 83.2602
# Training MAPE: 58.3295 Testing MAPE: 82.9217
# Training MAPE: 58.4000 Testing MAPE: 83.0904
# Training MAPE: 58.4084 Testing MAPE: 83.2133
# Training MAPE: 58.1066 Testing MAPE: 83.1169
# Training MAPE: 57.9738 Testing MAPE: 83.3349
# Training MAPE: 57.9551 Testing MAPE: 83.0159
# Training MAPE: 57.4493 Testing MAPE: 82.1767
# Training MAPE: 57.5347 Testing MAPE: 81.8460
# Training MAPE: 57.4707 Testing MAPE: 81.7972
# Training MAPE: 57.5279 Testing MAPE: 82.0798
# Training MAPE: 57.5629 Testing MAPE: 81.1983
# Training MAPE: 57.1055 Testing MAPE: 81.0702
# Training MAPE: 57.2437 Testing MAPE: 80.6380
# Training MAPE: 57.0354 Testing MAPE: 80.6717
# Training MAPE: 56.9331 Testing MAPE: 80.1178
# Training MAPE: 56.7092 Testing MAPE: 79.9229
# Training MAPE: 56.6565 Testing MAPE: 79.5548
# Training MAPE: 56.7285 Testing MAPE: 79.6576
# Training MAPE: 56.5085 Testing MAPE: 78.9648
# Training MAPE: 56.4956 Testing MAPE: 78.7274
# Training MAPE: 56.4173 Testing MAPE: 78.8678
# Training MAPE: 56.3056 Testing MAPE: 78.6287
# Training MAPE: 56.3845 Testing MAPE: 78.7948
# Training MAPE: 56.2316 Testing MAPE: 78.7374
# Training MAPE: 56.3690 Testing MAPE: 79.0637
# Training MAPE: 56.1083 Testing MAPE: 78.4265
# Training MAPE: 56.0651 Testing MAPE: 78.3992
# Training MAPE: 56.0476 Testing MAPE: 78.8177
# Training MAPE: 55.8631 Testing MAPE: 78.3588
# Training MAPE: 55.8173 Testing MAPE: 78.5173
# Training MAPE: 55.8878 Testing MAPE: 78.0138
# Training MAPE: 55.7941 Testing MAPE: 77.8650
# Training MAPE: 55.5750 Testing MAPE: 77.3663
# Training MAPE: 55.5451 Testing MAPE: 77.6489
# Training MAPE: 55.5197 Testing MAPE: 77.6913
# Training MAPE: 55.4855 Testing MAPE: 77.9821
# Training MAPE: 55.5886 Testing MAPE: 77.8223
# Training MAPE: 55.6115 Testing MAPE: 77.8905
# Training MAPE: 55.3953 Testing MAPE: 77.1142
# Training MAPE: 55.4507 Testing MAPE: 76.3981
# Training MAPE: 55.1719 Testing MAPE: 76.0170
# Training MAPE: 54.8910 Testing MAPE: 75.6216
# Training MAPE: 55.2245 Testing MAPE: 76.0130
# Training MAPE: 55.1678 Testing MAPE: 75.8100
# Training MAPE: 55.0891 Testing MAPE: 75.9914
# Training MAPE: 55.0977 Testing MAPE: 76.3142
# Training MAPE: 54.8577 Testing MAPE: 76.5560
# Training MAPE: 54.9469 Testing MAPE: 75.9237
# Training MAPE: 54.7936 Testing MAPE: 75.7010
# Training MAPE: 54.8338 Testing MAPE: 75.5630
# Training MAPE: 54.7089 Testing MAPE: 74.6985
# Training MAPE: 54.6770 Testing MAPE: 74.8410
# Training MAPE: 54.7547 Testing MAPE: 74.7932
# Training MAPE: 54.4370 Testing MAPE: 74.5113
# Training MAPE: 54.5220 Testing MAPE: 73.9905
# Training MAPE: 54.5253 Testing MAPE: 73.3527
# Training MAPE: 54.4057 Testing MAPE: 73.6369
# Training MAPE: 54.3689 Testing MAPE: 72.9730
# Training MAPE: 54.1892 Testing MAPE: 72.7336
# Training MAPE: 54.2275 Testing MAPE: 72.9175
# Training MAPE: 54.0920 Testing MAPE: 72.9666
# Training MAPE: 54.2084 Testing MAPE: 73.1226
# Training MAPE: 53.9408 Testing MAPE: 72.8408
# Training MAPE: 53.8335 Testing MAPE: 73.1572
# Training MAPE: 53.9450 Testing MAPE: 72.4867
# Training MAPE: 53.7987 Testing MAPE: 71.7464
# Training MAPE: 53.8541 Testing MAPE: 71.4072
# Training MAPE: 53.9167 Testing MAPE: 71.5470
# Training MAPE: 53.9728 Testing MAPE: 72.1078
# Training MAPE: 53.7114 Testing MAPE: 72.5158
# Training MAPE: 53.5759 Testing MAPE: 72.5166
# Training MAPE: 53.8612 Testing MAPE: 72.3790
# Training MAPE: 53.9190 Testing MAPE: 72.2747
# Training MAPE: 53.7594 Testing MAPE: 71.4529
# Training MAPE: 53.5888 Testing MAPE: 71.4482
# Training MAPE: 53.5546 Testing MAPE: 71.1903
# Training MAPE: 53.2881 Testing MAPE: 72.1246
# Training MAPE: 53.3427 Testing MAPE: 72.4291
# Training MAPE: 53.5226 Testing MAPE: 73.0764
# Training MAPE: 53.4288 Testing MAPE: 72.5046
# Training MAPE: 53.0199 Testing MAPE: 72.1886
# Training MAPE: 53.3847 Testing MAPE: 71.5956
# Training MAPE: 53.4719 Testing MAPE: 71.4641
# Training MAPE: 53.2103 Testing MAPE: 71.5163
# Training MAPE: 53.3284 Testing MAPE: 71.4762
# Training MAPE: 53.0964 Testing MAPE: 71.9311
# Training MAPE: 53.1929 Testing MAPE: 72.0271
# Training MAPE: 53.0043 Testing MAPE: 71.3884
# Training MAPE: 52.8927 Testing MAPE: 70.8407
# Training MAPE: 53.0513 Testing MAPE: 70.4052
# Training MAPE: 52.9274 Testing MAPE: 70.3258
# Training MAPE: 52.9190 Testing MAPE: 70.3476
# Training MAPE: 52.8147 Testing MAPE: 70.4801
# Training MAPE: 52.9047 Testing MAPE: 70.7445
# Training MAPE: 52.7747 Testing MAPE: 71.2753
# Training MAPE: 52.7209 Testing MAPE: 70.4955
# Training MAPE: 52.6421 Testing MAPE: 70.0164
# Training MAPE: 52.7887 Testing MAPE: 70.1192
# Training MAPE: 52.6168 Testing MAPE: 70.4968
# Training MAPE: 52.7979 Testing MAPE: 70.8190
# Training MAPE: 52.5610 Testing MAPE: 70.4857
# Training MAPE: 52.4838 Testing MAPE: 70.5943
# Training MAPE: 52.6600 Testing MAPE: 69.6564
# Training MAPE: 52.5761 Testing MAPE: 69.2988
# Training MAPE: 52.6151 Testing MAPE: 68.8509
# Training MAPE: 52.5874 Testing MAPE: 69.4321
# Training MAPE: 52.4168 Testing MAPE: 69.7640
# Training MAPE: 52.4534 Testing MAPE: 70.5767
# Training MAPE: 52.4424 Testing MAPE: 70.3448
# Training MAPE: 52.1932 Testing MAPE: 70.5479
# Training MAPE: 52.2329 Testing MAPE: 70.4333
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-26-20ec24918f43> in <module>
#      36                 l += single_loss.item()
#      37                 s += sum(y_train[-n_calc:,0])
# ---> 38     loss.backward()
#      39     optimizer.step()
#      40
#
# ~/.virtualenvs/python_3.6_TS/lib/python3.6/site-packages/torch/tensor.py in backward(self, gradient, retain_graph, create_graph)
#     148                 products. Defaults to ``False``.
#     149         """
# --> 150         torch.autograd.backward(self, gradient, retain_graph, create_graph)
#     151
#     152     def register_hook(self, hook):
#
# ~/.virtualenvs/python_3.6_TS/lib/python3.6/site-packages/torch/autograd/__init__.py in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables)
#      97     Variable._execution_engine.run_backward(
#      98         tensors, grad_tensors, retain_graph, create_graph,
# ---> 99         allow_unreachable=True)  # allow_unreachable flag
#     100
#     101
#
# KeyboardInterrupt:

# %%
mat_step =mat_train[13]
partial_sum= torch.tensor(mat_step[0][1])
for i in range(1,len(mat_step)):
    partial_sum += mat_step[i][1]
partial_sum
# Out:
# /home/CDBDX/remy.garnier/.virtualenvs/python_3.6_TS/lib/python3.6/site-packages/ipykernel_launcher.py:2: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
# tensor([[[96.6887]],
#
#         [[97.0137]],
#
#         [[92.6562]],
#
#         [[86.1099]],
#
#         [[86.0978]],
#
#         [[67.2631]],
#
#         [[62.7099]],
#
#         [[72.8341]],
#
#         [[65.6269]],
#
#         [[64.1968]],
#
#         [[62.6434]],
#
#         [[55.7985]],
#
#         [[58.1935]],
#
#         [[64.6675]],
#
#         [[66.2367]],
#
#         [[85.6285]],
#
#         [[84.7043]],
#
#         [[83.5637]],
#
#         [[75.3938]],
#
#         [[86.7936]]])
